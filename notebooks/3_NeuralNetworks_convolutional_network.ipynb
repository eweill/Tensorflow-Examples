# %%
# A Convolutional Network implementation example using TensorFlow library
# This example is using the MNIST database of handwritten digits

# Author: Edwin Weill

# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/home/eweill/data", one_hot=True)
# Out:
# Extracting /home/eweill/data/train-images-idx3-ubyte.gz
# Extracting /home/eweill/data/train-labels-idx1-ubyte.gz
# Extracting /home/eweill/data/t10k-images-idx3-ubyte.gz
# Extracting /home/eweill/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) # Dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    
    return out

# %%
# Store layer weights and biases
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 256 mnist test images
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.})
# Out:
# Iter 1280, Minibatch Loss= 35445.796875, Training Accuracy= 0.14062
# Iter 2560, Minibatch Loss= 10916.005859, Training Accuracy= 0.41406
# Iter 3840, Minibatch Loss= 9507.105469, Training Accuracy= 0.54688
# Iter 5120, Minibatch Loss= 5974.459473, Training Accuracy= 0.72656
# Iter 6400, Minibatch Loss= 3519.682129, Training Accuracy= 0.78125
# Iter 7680, Minibatch Loss= 7501.416016, Training Accuracy= 0.78125
# Iter 8960, Minibatch Loss= 3123.975098, Training Accuracy= 0.78125
# Iter 10240, Minibatch Loss= 1984.953979, Training Accuracy= 0.87500
# Iter 11520, Minibatch Loss= 1296.470947, Training Accuracy= 0.89062
# Iter 12800, Minibatch Loss= 3485.526855, Training Accuracy= 0.78906
# Iter 14080, Minibatch Loss= 840.709106, Training Accuracy= 0.93750
# Iter 15360, Minibatch Loss= 1130.304443, Training Accuracy= 0.92188
# Iter 16640, Minibatch Loss= 1660.043701, Training Accuracy= 0.91406
# Iter 17920, Minibatch Loss= 1382.425537, Training Accuracy= 0.93750
# Iter 19200, Minibatch Loss= 1400.604126, Training Accuracy= 0.89844
# Iter 20480, Minibatch Loss= 256.389099, Training Accuracy= 0.96094
# Iter 21760, Minibatch Loss= 3276.718262, Training Accuracy= 0.87500
# Iter 23040, Minibatch Loss= 715.220642, Training Accuracy= 0.93750
# Iter 24320, Minibatch Loss= 1014.611206, Training Accuracy= 0.92969
# Iter 25600, Minibatch Loss= 1556.391602, Training Accuracy= 0.89062
# Iter 26880, Minibatch Loss= 510.325897, Training Accuracy= 0.93750
# Iter 28160, Minibatch Loss= 1179.925659, Training Accuracy= 0.91406
# Iter 29440, Minibatch Loss= 1616.606934, Training Accuracy= 0.89062
# Iter 30720, Minibatch Loss= 982.130615, Training Accuracy= 0.89844
# Iter 32000, Minibatch Loss= 1017.790039, Training Accuracy= 0.92969
# Iter 33280, Minibatch Loss= 1152.371338, Training Accuracy= 0.92188
# Iter 34560, Minibatch Loss= 452.403381, Training Accuracy= 0.94531
# Iter 35840, Minibatch Loss= 255.335617, Training Accuracy= 0.97656
# Iter 37120, Minibatch Loss= 663.619629, Training Accuracy= 0.93750
# Iter 38400, Minibatch Loss= 139.485153, Training Accuracy= 0.96875
# Iter 39680, Minibatch Loss= 383.590118, Training Accuracy= 0.96094
# Iter 40960, Minibatch Loss= 1179.412354, Training Accuracy= 0.89844
# Iter 42240, Minibatch Loss= 753.585449, Training Accuracy= 0.94531
# Iter 43520, Minibatch Loss= 668.171753, Training Accuracy= 0.96094
# Iter 44800, Minibatch Loss= 362.650726, Training Accuracy= 0.94531
# Iter 46080, Minibatch Loss= 333.483032, Training Accuracy= 0.96094
# Iter 47360, Minibatch Loss= 878.893066, Training Accuracy= 0.92969
# Iter 48640, Minibatch Loss= 1304.624023, Training Accuracy= 0.93750
# Iter 49920, Minibatch Loss= 940.180786, Training Accuracy= 0.92969
# Iter 51200, Minibatch Loss= 313.976196, Training Accuracy= 0.95312
# Iter 52480, Minibatch Loss= 285.064758, Training Accuracy= 0.96094
# Iter 53760, Minibatch Loss= 78.067772, Training Accuracy= 0.97656
# Iter 55040, Minibatch Loss= 390.578796, Training Accuracy= 0.97656
# Iter 56320, Minibatch Loss= 690.991760, Training Accuracy= 0.96094
# Iter 57600, Minibatch Loss= 859.677307, Training Accuracy= 0.92188
# Iter 58880, Minibatch Loss= 611.335571, Training Accuracy= 0.94531
# Iter 60160, Minibatch Loss= 834.033691, Training Accuracy= 0.92188
# Iter 61440, Minibatch Loss= 373.563568, Training Accuracy= 0.96875
# Iter 62720, Minibatch Loss= 584.361389, Training Accuracy= 0.94531
# Iter 64000, Minibatch Loss= 204.698074, Training Accuracy= 0.96875
# Iter 65280, Minibatch Loss= 398.754395, Training Accuracy= 0.97656
# Iter 66560, Minibatch Loss= 115.563698, Training Accuracy= 0.98438
# Iter 67840, Minibatch Loss= 664.610474, Training Accuracy= 0.92969
# Iter 69120, Minibatch Loss= 108.861221, Training Accuracy= 0.97656
# Iter 70400, Minibatch Loss= 157.351898, Training Accuracy= 0.98438
# Iter 71680, Minibatch Loss= 230.197220, Training Accuracy= 0.96875
# Iter 72960, Minibatch Loss= 863.613464, Training Accuracy= 0.92969
# Iter 74240, Minibatch Loss= 308.269653, Training Accuracy= 0.97656
# Iter 75520, Minibatch Loss= 607.522217, Training Accuracy= 0.95312
# Iter 76800, Minibatch Loss= 473.139465, Training Accuracy= 0.96094
# Iter 78080, Minibatch Loss= 196.753494, Training Accuracy= 0.97656
# Iter 79360, Minibatch Loss= 239.043671, Training Accuracy= 0.98438
# Iter 80640, Minibatch Loss= 553.822754, Training Accuracy= 0.95312
# Iter 81920, Minibatch Loss= 148.460419, Training Accuracy= 0.97656
# Iter 83200, Minibatch Loss= 677.854980, Training Accuracy= 0.93750
# Iter 84480, Minibatch Loss= 590.173950, Training Accuracy= 0.94531
# Iter 85760, Minibatch Loss= 386.619537, Training Accuracy= 0.94531
# Iter 87040, Minibatch Loss= 525.573364, Training Accuracy= 0.96875
# Iter 88320, Minibatch Loss= 467.510376, Training Accuracy= 0.96875
# Iter 89600, Minibatch Loss= 428.572510, Training Accuracy= 0.96875
# Iter 90880, Minibatch Loss= 244.414291, Training Accuracy= 0.97656
# Iter 92160, Minibatch Loss= 479.244385, Training Accuracy= 0.96094
# Iter 93440, Minibatch Loss= 467.800415, Training Accuracy= 0.93750
# Iter 94720, Minibatch Loss= 590.937561, Training Accuracy= 0.95312
# Iter 96000, Minibatch Loss= 371.222656, Training Accuracy= 0.97656
# Iter 97280, Minibatch Loss= 292.695007, Training Accuracy= 0.95312
# Iter 98560, Minibatch Loss= 716.873718, Training Accuracy= 0.94531
# Iter 99840, Minibatch Loss= 81.811089, Training Accuracy= 0.96875
# Iter 101120, Minibatch Loss= 462.690521, Training Accuracy= 0.96875
# Iter 102400, Minibatch Loss= 416.585938, Training Accuracy= 0.94531
# Iter 103680, Minibatch Loss= 69.917252, Training Accuracy= 0.98438
# Iter 104960, Minibatch Loss= 231.016479, Training Accuracy= 0.98438
# Iter 106240, Minibatch Loss= 157.655640, Training Accuracy= 0.96094
# Iter 107520, Minibatch Loss= 250.006638, Training Accuracy= 0.96875
# Iter 108800, Minibatch Loss= 319.689636, Training Accuracy= 0.97656
# Iter 110080, Minibatch Loss= 428.785645, Training Accuracy= 0.95312
# Iter 111360, Minibatch Loss= 232.599121, Training Accuracy= 0.96875
# Iter 112640, Minibatch Loss= 138.410950, Training Accuracy= 0.96094
# Iter 113920, Minibatch Loss= 400.725067, Training Accuracy= 0.96094
# Iter 115200, Minibatch Loss= 540.963257, Training Accuracy= 0.94531
# Iter 116480, Minibatch Loss= 85.319351, Training Accuracy= 0.96875
# Iter 117760, Minibatch Loss= 108.381638, Training Accuracy= 0.98438
# Iter 119040, Minibatch Loss= 78.812202, Training Accuracy= 0.97656
# Iter 120320, Minibatch Loss= 317.775269, Training Accuracy= 0.93750
# Iter 121600, Minibatch Loss= 70.618614, Training Accuracy= 0.97656
# Iter 122880, Minibatch Loss= 251.505951, Training Accuracy= 0.94531
# Iter 124160, Minibatch Loss= 85.987213, Training Accuracy= 0.96875
# Iter 125440, Minibatch Loss= 263.604980, Training Accuracy= 0.97656
# Iter 126720, Minibatch Loss= 340.304230, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 379.521973, Training Accuracy= 0.95312
# Iter 129280, Minibatch Loss= 206.054657, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 185.293655, Training Accuracy= 0.96094
# Iter 131840, Minibatch Loss= 172.325974, Training Accuracy= 0.96875
# Iter 133120, Minibatch Loss= 183.437042, Training Accuracy= 0.97656
# Iter 134400, Minibatch Loss= 194.294754, Training Accuracy= 0.96875
# Iter 135680, Minibatch Loss= 238.689087, Training Accuracy= 0.95312
# Iter 136960, Minibatch Loss= 289.355530, Training Accuracy= 0.96875
# Iter 138240, Minibatch Loss= 112.361061, Training Accuracy= 0.98438
# Iter 139520, Minibatch Loss= 157.376602, Training Accuracy= 0.97656
# Iter 140800, Minibatch Loss= 180.990005, Training Accuracy= 0.96094
# Iter 142080, Minibatch Loss= 317.636688, Training Accuracy= 0.97656
# Iter 143360, Minibatch Loss= 301.722778, Training Accuracy= 0.97656
# Iter 144640, Minibatch Loss= 212.241226, Training Accuracy= 0.96875
# Iter 145920, Minibatch Loss= 243.987442, Training Accuracy= 0.97656
# Iter 147200, Minibatch Loss= 103.833130, Training Accuracy= 0.97656
# Iter 148480, Minibatch Loss= 237.330872, Training Accuracy= 0.96875
# Iter 149760, Minibatch Loss= 181.697266, Training Accuracy= 0.96875
# Iter 151040, Minibatch Loss= 144.058167, Training Accuracy= 0.98438
# Iter 152320, Minibatch Loss= 387.347656, Training Accuracy= 0.95312
# Iter 153600, Minibatch Loss= 161.862045, Training Accuracy= 0.96875
# Iter 154880, Minibatch Loss= 253.096954, Training Accuracy= 0.96875
# Iter 156160, Minibatch Loss= 159.420822, Training Accuracy= 0.97656
# Iter 157440, Minibatch Loss= 77.503647, Training Accuracy= 0.96875
# Iter 158720, Minibatch Loss= 136.594025, Training Accuracy= 0.97656
# Iter 160000, Minibatch Loss= 86.582092, Training Accuracy= 0.98438
# Iter 161280, Minibatch Loss= 148.691681, Training Accuracy= 0.97656
# Iter 162560, Minibatch Loss= 623.215088, Training Accuracy= 0.93750
# Iter 163840, Minibatch Loss= 199.416931, Training Accuracy= 0.98438
# Iter 165120, Minibatch Loss= 262.890350, Training Accuracy= 0.96875
# Iter 166400, Minibatch Loss= 352.442627, Training Accuracy= 0.95312
# Iter 167680, Minibatch Loss= 268.392517, Training Accuracy= 0.96094
# Iter 168960, Minibatch Loss= 40.212959, Training Accuracy= 0.96875
# Iter 170240, Minibatch Loss= 9.700317, Training Accuracy= 0.98438
# Iter 171520, Minibatch Loss= 188.987152, Training Accuracy= 0.96875
# Iter 172800, Minibatch Loss= 45.316643, Training Accuracy= 0.97656
# Iter 174080, Minibatch Loss= 24.754692, Training Accuracy= 0.98438
# Iter 175360, Minibatch Loss= 119.717323, Training Accuracy= 0.97656
# Iter 176640, Minibatch Loss= 230.895355, Training Accuracy= 0.95312
# Iter 177920, Minibatch Loss= 99.095818, Training Accuracy= 0.95312
# Iter 179200, Minibatch Loss= 217.466614, Training Accuracy= 0.99219
# Iter 180480, Minibatch Loss= 23.856613, Training Accuracy= 0.99219
# Iter 181760, Minibatch Loss= 70.800240, Training Accuracy= 0.97656
# Iter 183040, Minibatch Loss= 176.166107, Training Accuracy= 0.98438
# Iter 184320, Minibatch Loss= 64.026283, Training Accuracy= 0.98438
# Iter 185600, Minibatch Loss= 199.718536, Training Accuracy= 0.97656
# Iter 186880, Minibatch Loss= 108.393280, Training Accuracy= 0.97656
# Iter 188160, Minibatch Loss= 159.892029, Training Accuracy= 0.98438
# Iter 189440, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 190720, Minibatch Loss= 207.925201, Training Accuracy= 0.96875
# Iter 192000, Minibatch Loss= 86.821869, Training Accuracy= 0.98438
# Iter 193280, Minibatch Loss= 88.148697, Training Accuracy= 0.97656
# Iter 194560, Minibatch Loss= 71.252975, Training Accuracy= 0.96875
# Iter 195840, Minibatch Loss= 376.759949, Training Accuracy= 0.94531
# Iter 197120, Minibatch Loss= 202.979065, Training Accuracy= 0.94531
# Iter 198400, Minibatch Loss= 13.161873, Training Accuracy= 0.99219
# Iter 199680, Minibatch Loss= 253.965576, Training Accuracy= 0.93750
# Optimization Finished!
# Testing Accuracy: 0.988281
